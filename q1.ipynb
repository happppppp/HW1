# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#f = lambda x: x

def f(value, function):
    x = value
    return eval(function)

 
a = int(input('interval left: '))
b = int(input('interval right: '))
n = int(input('interval partition: '))
N = int(input('interval partition: '))
 # Use n*N+1 points to plot the function smoothly
#func_text = input('Enter a function: ')
#func_eval = eval(func_text)
#f = lambda x: func_eval

x = np.linspace(a,b,N+1)
y = f(x,input())

X = np.linspace(a,b,n*N+1)
Y = f(X,input())

plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.plot(X,Y,'b')
x_left = x[:-1] # Left endpoints
y_left = y[:-1]
plt.plot(x_left,y_left,'b.',markersize=10)
plt.bar(x_left,y_left,width=(b-a)/N,alpha=0.2,align='edge',edgecolor='b')
plt.title('Left Riemann Sum, N = {}'.format(N))

plt.subplot(1,3,2)
plt.plot(X,Y,'b')
x_mid = (x[:-1] + x[1:])/2 # Midpoints
y_mid = f(x_mid,input())
plt.plot(x_mid,y_mid,'b.',markersize=10)
plt.bar(x_mid,y_mid,width=(b-a)/N,alpha=0.2,edgecolor='b')
plt.title('Midpoint Riemann Sum, N = {}'.format(N))

plt.subplot(1,3,3)
plt.plot(X,Y,'b')
x_right = x[1:] # Left endpoints
y_right = y[1:]
plt.plot(x_right,y_right,'b.',markersize=10)
plt.bar(x_right,y_right,width=-(b-a)/N,alpha=0.2,align='edge',edgecolor='b')
plt.title('Right Riemann Sum, N = {}'.format(N))

plt.show()

# %%
dx = (b-a)/N
x_left = np.linspace(a,b-dx,N)
x_midpoint = np.linspace(dx/2,b - dx/2,N)
x_right = np.linspace(dx,b,N)

print("Partition with",N,"subintervals.")
left_riemann_sum = np.sum(f(x_left,input()) * dx)
print("Left Riemann Sum:",left_riemann_sum)

midpoint_riemann_sum = np.sum(f(x_midpoint,input()) * dx)
print("Midpoint Riemann Sum:",midpoint_riemann_sum)

right_riemann_sum = np.sum(f(x_right,input()) * dx)
print("Right Riemann Sum:",right_riemann_sum)
# Out:
# Partition with 5 subintervals.
# Left Riemann Sum: 10.400000000000002
# Midpoint Riemann Sum: 10.0
# Right Riemann Sum: 11.600000000000001

# %%
import matplotlib

# %%
from matplotlib import pyplot as plot
from scipy import stats

# %%
import matplotlib.pyplot as plt
import math

i=0
circle1 = plt.Circle((0, 0), 1, color='y')

fig, ax = plt.subplots()


def f(c):
    e=np.array([])
    g=np.array([])
    d=math.sqrt(1-(c*c))
    e=np.append(e,c)
    g=np.append(g,d)
    h=np.concatenate((e, g), axis=0)
    plt.xlim(-1.25,1.25)
    plt.ylim(-1.25,1.25)
    ax.set_aspect(1)
    ax.add_artist(circle1)
    plt.grid(linestyle='--',)
    plt.plot(e, g ,'b+')
    return h

N=int(input('bir sayı girin:'))   
for i in range(N):
    c = random.uniform(-1,1)
    print(f(c))
# Out:
# [-0.32923515  0.94424796]
# [-0.20999579  0.97770229]
# [-0.60200626  0.79849137]
# [0.30758963 0.95151911]
